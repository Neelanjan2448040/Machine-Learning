# %% [markdown]
# # Lab 1: Data Preprocessing and Exploratory Data Analysis

# %% [markdown]
# <h2 style="text-align: center;">Name: Neelanajn Dutta </h2>

# %% [markdown]
#  <h2 style="text-align: center;">Registration number: 2448040 </h2>

# %% [markdown]
# ### Import Libraries:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ### Data Acquisition and About Dataset:

# %%
df_hp=pd.read_csv("D:/housing_price.csv")

# %%
df_hp.head() #First five values
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_hp.tail() #Last five values
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
print("No. of Records:",df_hp.shape[0])
print("No. of Features:", df_hp.shape[1]) 
print('Features:', df_hp.columns)
# Out:
# No. of Records: 1460
# No. of Features: 81
# Features: Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
df_hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df_hp.describe() #sumarry statistics
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#Set display option to show all columns
pd.set_option('display.max_rows',None) #To display all rows
pd.set_option('display.max_columns',None) #To display all columns
#Check for unique values in each column
df_hp.nunique()
# Out:
# Id               1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
# Street              2
# Alley               2
# LotShape            4
# LandContour         4
# Utilities           2
# LotConfig           5
# LandSlope           3
# Neighborhood       25
# Condition1          9
# Condition2          8
# BldgType            5
# HouseStyle          8
# OverallQual        10
# OverallCond         9
# YearBuilt         112
# YearRemodAdd       61
# RoofStyle           6
# RoofMatl            8
# Exterior1st        15
# Exterior2nd        16
# MasVnrType          3
# MasVnrArea        327
# ExterQual           4
# ExterCond           5
# Foundation          6
# BsmtQual            4
# BsmtCond            4
# BsmtExposure        4
# BsmtFinType1        6
# BsmtFinSF1        637
# BsmtFinType2        6
# BsmtFinSF2        144
# BsmtUnfSF         780
# TotalBsmtSF       721
# Heating             6
# HeatingQC           5
# ...

# %% [markdown]
# ## Data Preprocessing:

# %% [markdown]
# ### Dropping not relevant features:

# %%
#Remove Id, Street, Utilities, Heating
df_hp.drop(['Id','Street','Utilities','Heating'],axis=1,inplace=True)

# %% [markdown]
# ### Missing Data:

# %%
#Checking for missing values
missing_values=df_hp.isnull().sum()
#Calculating missing percentage
missing_percentage=(missing_values/len(df_hp))*100
missing_data=pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage})
#Filter to display only columns with missing values
missing_data=missing_data[missing_data['Missing Values']>0]
#Display missing values for allcolumns
print(missing_data)
# Out:
#               Missing Values  Percentage
# LotFrontage              259   17.739726
# Alley                   1369   93.767123
# MasVnrType               872   59.726027
# MasVnrArea                 8    0.547945
# BsmtQual                  37    2.534247
# BsmtCond                  37    2.534247
# BsmtExposure              38    2.602740
# BsmtFinType1              37    2.534247
# BsmtFinType2              38    2.602740
# Electrical                 1    0.068493
# FireplaceQu              690   47.260274
# GarageType                81    5.547945
# GarageYrBlt               81    5.547945
# GarageFinish              81    5.547945
# GarageQual                81    5.547945
# GarageCond                81    5.547945
# PoolQC                  1453   99.520548
# Fence                   1179   80.753425
# MiscFeature             1406   96.301370

# %%
# Drop columns with more than 80% missing values
df_hp.drop(columns=['Alley', 'MiscFeature', 'PoolQC', 'Fence'], inplace=True)

# %%
# Remove records with missing values in specified columns
df_hp = df_hp.dropna(subset=['Electrical', 'MasVnrType', 'MasVnrArea'])

# %% [markdown]
# ### Imputation for numerical features:

# %%
# Impute numerical missing values
df_hp['LotFrontage'].fillna(df_hp['LotFrontage'].median(), inplace=True)
df_hp['GarageYrBlt'].fillna(0, inplace=True)

# %% [markdown]
# ### Imputation for categorical features:

# %%
# Impute categorical missing values
garage_cols = ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']
df_hp[garage_cols] = df_hp[garage_cols].fillna('None')

bsmt_cat_cols = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']
df_hp[bsmt_cat_cols] = df_hp[bsmt_cat_cols].fillna('None')

df_hp['FireplaceQu'].fillna('None', inplace=True)

# Verify missing values handled
print("Total missing values left:", df_hp.isnull().sum().sum())
# Out:
# Total missing values left: 0

# %% [markdown]
# ### Relation between Yearbuilt and SalePrice of the House:

# %%
df_hp.groupby('YearBuilt')['SalePrice'].median().plot()
plt.xlabel("Year Built")
plt.ylabel("SalePrice")
plt.title("House Price vs Year Built")
plt.show()

# %% [markdown]
# ## Target Feature: SalePrice

# %% [markdown]
# ### SalePrice distribution:

# %%
#Plot
plt.figure(figsize=(8,5))
sb.histplot(df_hp['SalePrice'],kde=True,bins=30)
plt.title("Distribution of SalePrice")
plt.xlabel("SalePrice")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Plot for relation btween Year Sold and SalePrice of the house:

# %%
df_hp.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel("Year Sold")
plt.ylabel("SalePrice")
plt.title("House Sale Price vs Year Sold")
# Out:
# Text(0.5, 1.0, 'House Sale Price vs Year Sold')

# %%
df_hp.groupby(['YrSold','BldgType'])['SalePrice'].mean()
# Out:
# YrSold  BldgType
# 2006    1Fam        232740.079545
#         2fmCon      142000.000000
#         Duplex      131928.571429
#         Twnhs       118562.500000
#         TwnhsE      182882.062500
# 2007    1Fam        231509.655172
#         2fmCon      168000.000000
#         Duplex      134343.571429
#         Twnhs       149700.000000
#         TwnhsE      187074.000000
# 2008    1Fam        219338.652632
#         Duplex      150475.000000
#         Twnhs       130800.000000
#         TwnhsE      217299.600000
# 2009    1Fam        237023.357798
#         Duplex      146959.250000
#         Twnhs       166062.500000
#         TwnhsE      173794.846154
# 2010    1Fam        217086.274194
#         Duplex      154300.000000
#         Twnhs       147000.000000
#         TwnhsE      219725.000000
# Name: SalePrice, dtype: float64

# %%
df_hp[df_hp['SalePrice']==0]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, LotShape, LandContour, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
sb.histplot(df_hp['YearBuilt'],kde=True,bins=30)
# Out:
# <Axes: xlabel='YearBuilt', ylabel='Count'>

# %% [markdown]
# ### Correlation with SalePrice:

# %%
# Select only numeric columns for the correlation matrix
numeric_df = df_hp.select_dtypes(include=['int64', 'float64'])

# Calculate the correlation matrix
corr_matrix = numeric_df.corr()

# Get absolute correlations with SalePrice and sort
top_corr_features = corr_matrix['SalePrice'].abs().sort_values(ascending=False)

# Print the most correlated features with SalePrice
print(top_corr_features)
# Out:
# SalePrice        1.000000
# OverallQual      0.793728
# GrLivArea        0.676352
# GarageCars       0.661897
# GarageArea       0.636327
# TotRmsAbvGrd     0.558937
# YearBuilt        0.546433
# 1stFlrSF         0.536835
# FullBath         0.536256
# TotalBsmtSF      0.535653
# YearRemodAdd     0.524610
# MasVnrArea       0.426364
# Fireplaces       0.390463
# WoodDeckSF       0.340192
# BsmtFinSF1       0.310067
# LotFrontage      0.309996
# 2ndFlrSF         0.299034
# OpenPorchSF      0.278066
# LotArea          0.256058
# MSSubClass       0.214592
# BsmtUnfSF        0.201947
# BsmtFullBath     0.196224
# HalfBath         0.170472
# GarageYrBlt      0.159622
# KitchenAbvGr     0.134741
# OverallCond      0.133560
# BedroomAbvGr     0.120267
# ScreenPorch      0.078786
# EnclosedPorch    0.062487
# BsmtHalfBath     0.046003
# BsmtFinSF2       0.043548
# YrSold           0.022674
# 3SsnPorch        0.020513
# MiscVal          0.018158
# PoolArea         0.015801
# ...

# %% [markdown]
# ### Takes high correlation values with respect to SalePrice from above

# %%
threshold=0.5
high_corr_values=[]
for feature in corr_matrix:
    high_corr_features=corr_matrix.index[(corr_matrix[feature].abs()>threshold)]
    high_corr_values.extend(high_corr_features)
high_corr_values=list(set(high_corr_values))
high_corr_values
# Out:
# ['GrLivArea',
#  'LotFrontage',
#  'Fireplaces',
#  'KitchenAbvGr',
#  'MiscVal',
#  'TotalBsmtSF',
#  'PoolArea',
#  'BedroomAbvGr',
#  'EnclosedPorch',
#  'OverallQual',
#  'YearBuilt',
#  'HalfBath',
#  'OpenPorchSF',
#  'BsmtUnfSF',
#  'YearRemodAdd',
#  'MSSubClass',
#  'YrSold',
#  '3SsnPorch',
#  'SalePrice',
#  '2ndFlrSF',
#  'BsmtHalfBath',
#  'TotRmsAbvGrd',
#  'ScreenPorch',
#  'OverallCond',
#  'FullBath',
#  'LotArea',
#  'BsmtFinSF2',
#  'WoodDeckSF',
#  '1stFlrSF',
#  'GarageArea',
#  'MoSold',
#  'GarageCars',
#  'MasVnrArea',
#  'BsmtFullBath',
#  'BsmtFinSF1',
#  'GarageYrBlt']

# %%
# Select top 10 correlated features
top_corr_features = top_corr_features.sort_values(ascending=False).head(10)
plt.figure(figsize=(10,5))
sb.barplot(x=top_corr_features.index, y=top_corr_features.values)
plt.xticks(rotation=45)
plt.title("Top 10 features correlated with SalesPrice")
plt.ylabel("Correlation")
plt.show()
